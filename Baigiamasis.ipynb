# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Nachalnik\Desktop\Mokymai\Pyton\Baigiamasis\supermarket_sales - Sheet1.csv')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df[['City','Gender','Product line','Unit price','Quantity','Tax 5%','Total','Payment','cogs','Rating']]
# Out:
#           City  Gender            Product line  Unit price  Quantity   Tax 5%  \
# 0       Yangon  Female       Health and beauty       74.69         7  26.1415
# 1    Naypyitaw  Female  Electronic accessories       15.28         5   3.8200
# 2       Yangon    Male      Home and lifestyle       46.33         7  16.2155
# 3       Yangon    Male       Health and beauty       58.22         8  23.2880
# 4       Yangon    Male       Sports and travel       86.31         7  30.2085
# ..         ...     ...                     ...         ...       ...      ...
# 995  Naypyitaw    Male       Health and beauty       40.35         1   2.0175
# 996   Mandalay  Female      Home and lifestyle       97.38        10  48.6900
# 997     Yangon    Male      Food and beverages       31.84         1   1.5920
# 998     Yangon    Male      Home and lifestyle       65.82         1   3.2910
# 999     Yangon  Female     Fashion accessories       88.34         7  30.9190
#
# ...

# %%
#Ka zmones dazniausiai perka
#Kokia lytis dazniausiai apsipirkineja
#Kas daugiausia isleidzia
#Is kokio miesto daugiausia apsipirkineja

# %%
df.groupby('Product line').agg({'Quantity': np.sum,
                                'Total' : np.sum,
                                'Tax 5%' : np.sum,
                                'cogs'  : np.sum})
# Out:
#                         Quantity       Total     Tax 5%      cogs
# Product line
# Electronic accessories       971  54337.5315  2587.5015  51750.03
# Fashion accessories          902  54305.8950  2585.9950  51719.90
# Food and beverages           952  56144.8440  2673.5640  53471.28
# Health and beauty            854  49193.7390  2342.5590  46851.18
# Home and lifestyle           911  53861.9130  2564.8530  51297.06
# Sports and travel            920  55122.8265  2624.8965  52497.93

# %%
sns.countplot(y = 'Product line', data = df, hue = 'Gender')
plt.xlabel('Genders')
plt.title('Customers', fontsize=16)
plt.style.use('dark_background')
plt.legend(loc = 'upper left')

# %%
df.groupby('Gender').agg({'Quantity': np.sum,
                          'Total'  : np.sum})
# Out:
#         Quantity       Total
# Gender
# Female      2869  167882.925
# Male        2641  155083.824

# %%
sns.countplot(y = 'Product line', data = df, hue = 'City')
plt.xlabel('Invoices')
plt.title('Sales', fontsize=16)
plt.legend(loc = 'upper left')

# %%
sns.displot(df['Payment'], color = 'orange')
plt.style.use('dark_background')
plt.xlabel('Payment type')
plt.ylabel('Payments')
# Out:
# Text(4.944444444444445, 0.5, 'Payments')

# %%
df.rename(columns={'Customer type':'Customer'}, inplace = True)
df
# Out:
#       Invoice ID Branch       City Customer  Gender            Product line  \
# 0    750-67-8428      A     Yangon   Member  Female       Health and beauty
# 1    226-31-3081      C  Naypyitaw   Normal  Female  Electronic accessories
# 2    631-41-3108      A     Yangon   Normal    Male      Home and lifestyle
# 3    123-19-1176      A     Yangon   Member    Male       Health and beauty
# 4    373-73-7910      A     Yangon   Normal    Male       Sports and travel
# ..           ...    ...        ...      ...     ...                     ...
# 995  233-67-5758      C  Naypyitaw   Normal    Male       Health and beauty
# 996  303-96-2227      B   Mandalay   Normal  Female      Home and lifestyle
# 997  727-02-1313      A     Yangon   Member    Male      Food and beverages
# 998  347-56-2442      A     Yangon   Normal    Male      Home and lifestyle
# 999  849-09-3807      A     Yangon   Member  Female     Fashion accessories
#
# ...

# %%
df.Customer.value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer, dtype: int64

# %%
df.Customer[df.Gender == 'Male'].value_counts()
# Out:
# Normal    259
# Member    240
# Name: Customer, dtype: int64

# %%
df.Customer[df.Gender == 'Female'].value_counts()
# Out:
# Member    261
# Normal    240
# Name: Customer, dtype: int64

# %%
df.City[df.City == 'Yangon'].value_counts()
# Out:
# Yangon    340
# Name: City, dtype: int64

# %%
df.City[df.City == 'Naypyitaw'].value_counts()
# Out:
# Naypyitaw    328
# Name: City, dtype: int64

# %%
df.City[df.City == 'Mandalay'].value_counts()
# Out:
# Mandalay    332
# Name: City, dtype: int64

# %%
data = [340, 328, 332]
keys = ['Yangon', 'Naypyitaw', 'Mandalay']
plt.title('2019 Sales by city', fontsize=16)
palette_color = sns.color_palette('bright')

plt.pie(data, labels=keys, colors=palette_color, autopct='%.0f%%')

plt.show()

# %%
df.groupby('Rating').Rating.value_counts()
# Out:
# Rating  Rating
# 4.0     4.0       11
# 4.1     4.1       17
# 4.2     4.2       22
# 4.3     4.3       18
# 4.4     4.4       17
#                   ..
# 9.6     9.6       17
# 9.7     9.7       14
# 9.8     9.8       19
# 9.9     9.9       16
# 10.0    10.0       5
# Name: Rating, Length: 61, dtype: int64

# %%
df[df.Rating >= 1].Rating.mean()
# Out:
# 6.9727

# %%
df[df.City == 'Yangon'].Rating.mean()
# Out:
# 7.027058823529413

# %%
df[df.City == 'Naypyitaw'].Rating.mean()
# Out:
# 7.072865853658537

# %%
df[df.City == 'Mandalay'].Rating.mean()
# Out:
# 6.818072289156625
